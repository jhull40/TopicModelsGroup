# %%
from gensim import models, corpora
import pandas as pd
import pyLDAvis.gensim

# %%
def prep_corpus_csv(fname):
    """
    reads in a csv file, and makes a corpus that is usable in gensim
    the third column here is the raw text that will be used to generate the topic models
    """

    d = pd.read_csv(fname)
        
    docs = []
    for i in range(len(d.index)):
        docs.append(d.iloc[i,2].split())
    
    for doc in docs:
        while '<NUMBER>' in doc:
            doc.remove('<NUMBER>')
        while 'patient' in doc:
            doc.remove('patient')
        while 'cell' in doc:
            doc.remove('cell')

    dictionary = corpora.Dictionary(docs)
    corpus = [dictionary.doc2bow(doc) for doc in docs]

    return corpus, dictionary, docs

# %%
"""
this dataset comes from scraped abstracts to articles published in PubMed, an open source journal for biology and medical articles
james then did a keyword search for a few key terms (HIV, TBI, microbiome, etc) to ensure there were at least some common topics
"""

corp, dictionary, docs = prep_corpus_csv('data/pubmed_sample_data.csv')

# %%
lda_model = models.LdaModel(corpus=corp, 
 num_topics=6, 
 id2word=dictionary, 
 distributed=False, 
 chunksize=2000, 
 passes=5, 
 update_every=1, 
 alpha='auto', 
 eta=None, 
 decay=0.5, 
 offset=1.0, 
 eval_every=10, 
 iterations=50, 
 gamma_threshold=0.001, 
 minimum_probability=0.01, 
 random_state=2, 
 ns_conf=None, 
 minimum_phi_value=0.01, 
 per_word_topics=False, 
 callbacks=None)

# %%
lda_visualization = pyLDAvis.gensim.prepare(lda_model, corp, dictionary, sort_topics=False)
pyLDAvis.display(lda_visualization)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el635571402585988379683656095300"></div>
# <script type="text/javascript">
#
# var ldavis_el635571402585988379683656095300_data = {"mdsDat": {"x": [-0.11350839207912104, -0.023689895082497928, 0.044312097690007116, 0.04170591848281936, 0.010710328850115849, 0.04046994213867669], "y": [0.04814863215965857, -0.10363323012235967, 0.03310899983756768, 0.03263302269473061, -0.020067849069486648, 0.009810424499889434], "topics": [1, 2, 3, 4, 5, 6], "cluster": [1, 1, 1, 1, 1, 1], "Freq": [8.387987206346333, 17.137446057559664, 16.38240029703981, 14.92904833235838, 19.504946107581823, 23.658171999113986]}, "tinfo": {"Term": ["HIV", "TBI", "vaccine", "gut", "breast", "microbiome", "HCC", "cancer", "liver", "CI", "risk", "PrEP", "woman", "care", "antibiotic", "microbiota", "receptor", "mortality", "HPV", "age", "treatment", "de", "service", "injury", "disease", "influenza", "vaccination", "prevalence", "type", "brain", "col\u00f3nica", "la", "los", "walnut", "HLH", "IPD", "descompresi\u00f3n", "el", "cebranopadol", "del", "literacy", "UC-MSCs", "KCs", "TGF-\u03b22", "acculturation", "est\u00e1ndar", "enculturation", "IVP", "imbmscs", "tratamiento", "homeless", "anti-denv", "SDU", "imbmsc41", "LukM", "HER3", "PCV10", "PCV13", "acetochlor", "NOP", "en", "HER2", "OUD", "transgender", "breast", "de", "hen", "colonic", "CDK4/6", "calf", "RH", "stroke", "cancer", "decompression", "woman", "level", "microbiome", "receptor", "strain", "therapy", "gut", "liver", "nanoparticles", "type", "risk", "serum", "expression", "response", "sample", "vaccine", "microbiota", "mouse", "peptide", "protein", "acid", "human", "HIV", "health", "potential", "disease", "decrease", "infection", "activity", "virus", "immune", "EN", "ASD", "GZW", "PN", "CVID", "MAP", "NCH", "dopamine", "acupuncture", "axonal", "Ca2+", "dermatitis", "FM", "IRIS", "SCT", "AA", "IRD", "OT", "earthworm", "rptfe", "ADE2", "Apgar", "TACE", "PRBC", "PPRV", "connectivity", "IgAN", "counteract", "granatum", "FDG-PET", "GI", "duct", "burn", "PD", "CHA", "gut", "LTA4H", "microbe", "antioxidant", "certainty", "compound", "activity", "microbiome", "microbiota", "human", "brain", "graft", "injury", "receptor", "discovery", "protein", "CRISPR", "mechanism", "target", "pharmacological", "enzyme", "model", "system", "function", "genetic", "subject", "potential", "TBI", "gene", "day", "disease", "liver", "review", "interaction", "mortality", "pathway", "drug", "follow", "response", "mouse", "role", "treatment", "level", "infection", "ATV", "C8mim", "ICI", "A3F", "SBP", "Vif", "T2DM", "\u03b2-cell", "ATM", "VMMC", "CHB", "HGSNAT", "HEU", "AHB", "MVC", "HIV-2", "MenB", "NAT", "regorafenib", "overload", "e-gp41", "FVIII", "PUs", "HU", "rechallenge", "pleural", "CICs", "apoaequorin", "LNG", "TFS", "urinary", "AlO", "iron", "cessation", "EVs", "antibiotic", "HF", "mtbi", "prevalence", "HIV", "chronic", "pulmonary", "disease", "age", "clinical", "treatment", "hypertension", "liver", "receive", "month", "TB", "year", "MS", "evidence", "type", "disorder", "CI", "blood", "infant", "risk", "case", "therapy", "factor", "individual", "infection", "child", "drug", "protein", "data", "review", "develop", "intervention", "present", "gene", "endometrial", "rtms", "ARG", "koala", "sirna/np", "PaCa", "decidualization", "C-glycosyl", "VTE", "flavone", "RDX", "GSNO", "Vpr", "A\u03b2", "TVS", "esfs", "resect", "RCAN1.4", "HDV", "thermophilic", "HMGA2", "KoRV", "EAC", "K-877", "HSV-2", "hydrogel", "microalbuminuria", "ischemia-reperfusion", "chiropractic", "EGFR", "HSV-1", "GPRC5a", "HCC", "hyponatremia", "dupontii", "MTBI", "onabotulinumtoxina", "cesarean", "mortality", "CI", "risk", "measles", "SP", "treatment", "ICP", "event", "aor", "model", "mouse", "NAFLD", "infection", "vaccine", "cardiovascular", "system", "data", "TBI", "HCV", "trial", "disease", "liver", "level", "rate", "HIV", "ratio", "outcome", "population", "gene", "age", "year", "virus", "strategy", "cancer", "vaccination", "time", "factor", "clinical", "potential", "expression", "therapy", "D3", "violence", "PTS", "peanut", "CsCP", "R ...
